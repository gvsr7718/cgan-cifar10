# %% [markdown]
# # Notebook 01: CIFAR-10 Data Exploration & Preprocessing Analysis
#
# This notebook will explore the CIFAR-10 dataset, inspect class distributions, visualize real sample images from all 10 classes, and test data transformation pipelines.

# %%
# TODO: Import libraries (torch, torchvision, matplotlib, numpy, yaml)
# TODO: Load configuration from configs/config.yaml

# %%
# TODO: Download and load CIFAR-10 training and test datasets
# TODO: Inspect dataset shape, mean, standard deviation, and class distribution

# %%
# TODO: Plot a 10x10 sample grid showing 10 sample images for each of the 10 classes
# TODO: Verify normalization range [-1, 1] and de-normalization for visualization
