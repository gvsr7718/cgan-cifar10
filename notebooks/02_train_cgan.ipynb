# %% [markdown]
# # Notebook 02: Conditional GAN (cGAN) Model Training (Google Colab / GPU)
#
# This notebook will provide an interactive environment for initializing the Generator and Discriminator, configuring optimizers, executing the training loop, and visualizing generated samples across epochs.

# %%
# TODO: Set up Google Colab GPU environment or local CUDA device
# TODO: Clone/pull project repository and install requirements

# %%
# TODO: Load configuration from configs/config.yaml and set random seeds
# TODO: Instantiate Generator, Discriminator, Loss functions, and Optimizers

# %%
# TODO: Run training loop with periodic sample generation and loss logging
# TODO: Save best and final checkpoints to checkpoints/ directory
